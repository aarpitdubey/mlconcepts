# %% [markdown]
# # Linear Regression

# %%
# Importing required Libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# Data Generation (X, Y)
def generateDataset(m):
    # array of X
    X = np.random.randn(m) * 10
    noise = np.random.randn(m) * 5
    Y = 3 * X + 1 + noise
    return X, Y

# %%
X, Y = generateDataset(100)
print(X.shape, Y.shape)
# Out:
# (100,) (100,)

# %%
print(f"Mean : {X.mean()} and Standard Deviation : {X.std()}")
# Out:
# Mean : -0.37417778511638994 and Standard Deviation : 10.992759409923874

# %%
def plotData(X, Y, color="orange", title="Data"):
    plt.xlabel('Marks')
    plt.ylabel('Work Efficiency')
    plt.scatter(X, Y, color=color)
    plt.title(title)
    plt.show()
    
plotData(X, Y)

# %%
def normalizeData(X):
    X = (X - X.mean())//X.std()
    return X

# %%
plotData(X, Y)
X = normalizeData(X)
plotData(X, Y)

# %%
print(f"Mean : {X.mean()} and Standard Deviation : {X.std()}")
# Out:
# Mean : -0.54 and Standard Deviation : 1.0141005867269777
